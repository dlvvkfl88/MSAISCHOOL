# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = np.random.normal(loc=0, scale=1, size=1000)
# 데이터 분포 시각화
sns.histplot(data)
plt.show()

# 데이터 통계 지표계산
mean = np.mean(data)
std= np.std(data)
print("평균;", mean)
print("표준편차;", std)
# Out:
# 평균; -0.04357248622631532
# 표준편차; 0.9755820131053892

# %%
# 데이터 생성
data = np.random.normal(loc=0, scale=1, size=10000)
print(data)
# Out:
# [ 0.18143029  0.23009209  0.46936734 ... -1.88291344  0.14772915
#  -0.54460618]

# %%
# 중심 경향성 계산
# 평균(mean) 중앙값 최빈값

mean = np.mean(data)
median = np.median(data)
mode = np.round(np.mean(data))

print(mean,median,mode)
# Out:
# -0.0020292893835725783 -0.004724881906643169 -0.0

# %%
fig, ax = plt.subplots()
ax.hist(data, bins=50)
ax.axvline(mean, color='red', linestyle='dashed', linewidth=2)
ax.axvline(median, color='green', linestyle='dashed', linewidth=2)
ax.axvline(mode, color='purple', linestyle='dashed', linewidth=2)
ax.legend(['Mean: {:.2f}'.format(mean), 'Median: {:.2f}'.format(median), 'Mode: {}'.format(mode)])
ax.set_xlabel('Data Values')
ax.set_ylabel('Frequency')
ax.set_title('Data Distribution')
plt.show()

# %%
# 두변수간 상관관계
np.random.seed(0)
x = np.random.normal(loc=0,scale=1,size=100)
y = x + np.random.normal(loc=0, scale=0.5 ,size=100)

# 산포도 그리기
fig, ax = plt.subplots()
ax.scatter(x, y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Scatter Plot')
plt.show()
