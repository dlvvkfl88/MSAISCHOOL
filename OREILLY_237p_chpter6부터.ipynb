# %% [markdown]
# <a href="https://colab.research.google.com/github/dlvvkfl88/MSAISCHOOL/blob/main/OREILLY_237p_chpter6%EB%B6%80%ED%84%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat examples/ex1.csv
# Out:
# cat: examples/ex1.csv: No such file or directory

# %% [markdown]
# ## 6.1.1 텍스트 파일 조금씩 읽어오기

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('/content/ex6.csv')

# %%
result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
pd.read_csv('/content/ex6.csv', nrows=5)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %% [markdown]
# ## 6.1.2데이터를 텍스트형태로 기록하기

# %%
data = pd.read_csv('/content/ex5.csv')

data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# ## 6.1.4 json 데이터

# %%
obj = """
{"name":"Wes",
"places_lived" : ["United States", "Spain","Germany"],
"Pet": null,
"sibilings": [{"name":"Scott", "age":30, "pets":["Zeus", "Zuko"]},
              {"name":"Katie", "age":38 ,
               "pets": ["Sixes", "Stache", "Cisco"]}]
               }
"""

# %%
import json

result = json.loads(obj)

result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'Pet': None,
#  'sibilings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result) # json.load(obj)가 json을 Python객체로 변화시키면 asjson은 반대이다 json.dumps(result)

# %%
siblings = pd.DataFrame(result['sibilings'], columns=['name','age'])

siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
# !cat examples/example.json
# Out:
# cat: examples/example.json: No such file or directory

# %%
print(data.to_json())

print(data.to_json(orient='records'))
# Out:
# {"something":{"0":"one","1":"two","2":"three"},"a":{"0":1,"1":5,"2":9},"b":{"0":2,"1":6,"2":10},"c":{"0":3.0,"1":null,"2":11.0},"d":{"0":4,"1":8,"2":12},"message":{"0":null,"1":"world","2":"foo"}}
# [{"something":"one","a":1,"b":2,"c":3.0,"d":4,"message":null},{"something":"two","a":5,"b":6,"c":null,"d":8,"message":"world"},{"something":"three","a":9,"b":10,"c":11.0,"d":12,"message":"foo"}]

# %% [markdown]
# ## 6.1.5 XML과 HTML : 웹스크래핑

# %%
# !conda install lxml
# !pip install beautifulsoup4 html5lib
# Out:
# /bin/bash: line 1: conda: command not found
# ...
